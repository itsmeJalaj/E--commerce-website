# %% [markdown]
# Walmart is an American multinational retail corporation that operates a vast network of supercenters, discount department stores, and grocery stores across the United States and globally. Founded by Sam Walton in 1962, Walmart has grown into one of the largest retailers in the world, serving over 100 million customers worldwide.
#             The company is known for its low-price strategy, extensive product selection, and efficient supply chain management. Walmart's business model focuses on cost leadership, ensuring affordability for customers while maintaining profitability. Over the years, it has expanded internationally, adapting to different markets while maintaining its core values of customer satisfaction and accessibility.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the data
data= pd.read_csv('walmart_data.txt')
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                               2               0                 3      8370
# ...

# %%
data.shape
# Out:
# (550068, 10)

# %%
data.size
# Out:
# 5500680

# %%
# checking all the columns of the data
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category',
#        'Purchase'],
#       dtype='object')

# %%
#checking datatypes of all the columns
data.dtypes
# Out:
# User_ID                        int64
# Product_ID                    object
# Gender                        object
# Age                           object
# Occupation                     int64
# City_Category                 object
# Stay_In_Current_City_Years    object
# Marital_Status                 int64
# Product_Category               int64
# Purchase                       int64
# dtype: object

# %%
# checking unique value and their their respective numbers

# %%
data['User_ID'].nunique()
# Out:
# 5891

# %%
data['User_ID'].value_counts()
# Out:
# User_ID
# 1001680    1026
# 1004277     979
# 1001941     898
# 1001181     862
# 1000889     823
#            ...
# 1002690       7
# 1002111       7
# 1005810       7
# 1004991       7
# 1000708       6
# Name: count, Length: 5891, dtype: int64

# %%
data['Product_ID'].nunique()
# Out:
# 3631

# %%
data['Product_ID'].value_counts()
# Out:
# Product_ID
# P00265242    1880
# P00025442    1615
# P00110742    1612
# P00112142    1562
# P00057642    1470
#              ...
# P00314842       1
# P00298842       1
# P00231642       1
# P00204442       1
# P00066342       1
# Name: count, Length: 3631, dtype: int64

# %%
data['Age'].nunique()
# Out:
# 7

# %%
data['Age'].value_counts()
# Out:
# Age
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: count, dtype: int64

# %%
data['Occupation'].nunique()
# Out:
# 21

# %%
data['Occupation'].value_counts(ascending= False)
# Out:
# Occupation
# 4     72308
# 0     69638
# 7     59133
# 1     47426
# 17    40043
# 20    33562
# 12    31179
# 14    27309
# 2     26588
# 16    25371
# 6     20355
# 3     17650
# 10    12930
# 5     12177
# 15    12165
# 11    11586
# 19     8461
# 13     7728
# 18     6622
# 9      6291
# 8      1546
# Name: count, dtype: int64

# %%
data['City_Category'].nunique()
# Out:
# 3

# %%
data['City_Category'].value_counts()
# Out:
# City_Category
# B    231173
# C    171175
# A    147720
# Name: count, dtype: int64

# %%
data['Stay_In_Current_City_Years'].nunique()
# Out:
# 5

# %%
data['Stay_In_Current_City_Years'].value_counts()
# Out:
# Stay_In_Current_City_Years
# 1     193821
# 2     101838
# 3      95285
# 4+     84726
# 0      74398
# Name: count, dtype: int64

# %%
data['Marital_Status'].nunique()
# Out:
# 2

# %%
data['Marital_Status'].value_counts()
# Out:
# Marital_Status
# 0    324731
# 1    225337
# Name: count, dtype: int64

# %%
data['Product_Category'].nunique()
# Out:
# 20

# %%
data['Product_Category'].value_counts()
# Out:
# Product_Category
# 5     150933
# 1     140378
# 8     113925
# 11     24287
# 2      23864
# 6      20466
# 3      20213
# 4      11753
# 16      9828
# 15      6290
# 13      5549
# 10      5125
# 12      3947
# 7       3721
# 18      3125
# 20      2550
# 19      1603
# 14      1523
# 17       578
# 9        410
# Name: count, dtype: int64

# %%
data['Purchase'].nunique()
# Out:
# 18105

# %%
data['Purchase'].value_counts()
# Out:
# Purchase
# 7011     191
# 7193     188
# 6855     187
# 6891     184
# 7012     183
#         ...
# 23491      1
# 18345      1
# 3372       1
# 855        1
# 21489      1
# Name: count, Length: 18105, dtype: int64

# %%
data.describe().T
# Out:
#                      count          mean          std        min        25%  \
# User_ID           550068.0  1.003029e+06  1727.591586  1000001.0  1001516.0
# Occupation        550068.0  8.076707e+00     6.522660        0.0        2.0
# Marital_Status    550068.0  4.096530e-01     0.491770        0.0        0.0
# Product_Category  550068.0  5.404270e+00     3.936211        1.0        1.0
# Purchase          550068.0  9.263969e+03  5023.065394       12.0     5823.0
#
#                         50%        75%        max
# User_ID           1003077.0  1004478.0  1006040.0
# Occupation              7.0       14.0       20.0
# Marital_Status          0.0        1.0        1.0
# Product_Category        5.0        8.0       20.0
# Purchase             8047.0    12054.0    23961.0

# %%
data.describe(include="object").T
# Out:
#                              count unique        top    freq
# Product_ID                  550068   3631  P00265242    1880
# Gender                      550068      2          M  414259
# Age                         550068      7      26-35  219587
# City_Category               550068      3          B  231173
# Stay_In_Current_City_Years  550068      5          1  193821

# %%
data.groupby('Gender')['Purchase'].describe()
# Out:
#            count         mean          std   min     25%     50%      75%  \
# Gender
# F       135809.0  8734.565765  4767.233289  12.0  5433.0  7914.0  11400.0
# M       414259.0  9437.526040  5092.186210  12.0  5863.0  8098.0  12454.0
#
#             max
# Gender
# F       23959.0
# M       23961.0

# %%
# Converting columns to 'category' columns

# %%
data['Gender']=data['Gender'].astype('category')

# %%
data['Age']=data['Age'].astype('category')

# %%
data['Age']=data['Age'].astype(str)

# %%
data['Stay_In_Current_City_Years']=data['Stay_In_Current_City_Years'].astype('category')

# %%
data['Marital_Status']=data['Marital_Status'].astype('category')

# %%
data['Marital_Status'] = data['Marital_Status'].astype(str)

# %%
data['Product_Category']=data['Product_Category'].astype('category')

# %%
sns.histplot(data['Purchase'] , bins=50)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.countplot(x=data['Age'], order=sorted(data['Age'].unique()))
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x=data['Gender'])
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=data['Product_Category'] )
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plt.figure(figsize=(30,5))
sns.countplot(x=data['Product_ID'])
plt.xticks(rotation=90)
plt.show()

# %%
data['Gender'].value_counts()
# Out:
# Gender
# M    414259
# F    135809
# Name: count, dtype: int64

# %%
data['Gender'].value_counts(normalize = True)*100
# Out:
# Gender
# M    75.310507
# F    24.689493
# Name: proportion, dtype: float64

# %%
data['Gender'].astype('category')
# Out:
# 0         F
# 1         F
# 2         F
# 3         F
# 4         M
#          ..
# 550063    M
# 550064    F
# 550065    F
# 550066    F
# 550067    F
# Name: Gender, Length: 550068, dtype: category
# Categories (2, object): ['F', 'M']

# %%
data['Gender'].value_counts()
# Out:
# Gender
# M    414259
# F    135809
# Name: count, dtype: int64

# %%
data['Product_ID'].nunique()
# Out:
# 3631

# %%
data['Marital_Status'].value_counts()
# Out:
# Marital_Status
# 0    324731
# 1    225337
# Name: count, dtype: int64

# %%
data['Gender'].dtype
# Out:
# CategoricalDtype(categories=['F', 'M'], ordered=False, categories_dtype=object)

# %%
data.describe()
# Out:
#             User_ID     Occupation       Purchase
# count  5.500680e+05  550068.000000  550068.000000
# mean   1.003029e+06       8.076707    9263.968713
# std    1.727592e+03       6.522660    5023.065394
# min    1.000001e+06       0.000000      12.000000
# 25%    1.001516e+06       2.000000    5823.000000
# 50%    1.003077e+06       7.000000    8047.000000
# 75%    1.004478e+06      14.000000   12054.000000
# max    1.006040e+06      20.000000   23961.000000

# %%
data.dtypes
# Out:
# User_ID                          int64
# Product_ID                      object
# Gender                        category
# Age                             object
# Occupation                       int64
# City_Category                   object
# Stay_In_Current_City_Years    category
# Marital_Status                  object
# Product_Category              category
# Purchase                         int64
# dtype: object

# %%
print(data['Gender'].dtype)
# Out:
# category

# %%
df=data.copy()

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years Marital_Status Product_Category  Purchase
# 0                               2              0                3      8370
# ...

# %%
df['Gender'] = df['Gender'].astype('category')

# %%
df['Gender']=df['Gender'].cat.codes

# %%
df['Gender']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 550063    1
# 550064    0
# 550065    0
# 550066    0
# 550067    0
# Name: Gender, Length: 550068, dtype: int8

# %%
df['Marital_Status'] = df['Marital_Status'].astype('category')

# %%
df['Marital_Status'].dtype
# Out:
# CategoricalDtype(categories=['0', '1'], ordered=False, categories_dtype=object)

# %%
df['Marital_Status']=df['Marital_Status'].cat.codes

# %%
df['Marital_Status']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 550063    1
# 550064    0
# 550065    1
# 550066    0
# 550067    1
# Name: Marital_Status, Length: 550068, dtype: int8

# %%
df['City_Category'] = df['City_Category'].astype('category')

# %%
df['City_Category']=df['City_Category'].cat.codes

# %%
df['City_Category']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         2
#          ..
# 550063    1
# 550064    2
# 550065    1
# 550066    2
# 550067    1
# Name: City_Category, Length: 550068, dtype: int8

# %%
df['Age'] = df['Age'].astype('category')

# %%
df['Age']=df['Age'].cat.codes

# %%
df['Age']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         6
#          ..
# 550063    5
# 550064    2
# 550065    2
# 550066    6
# 550067    4
# Name: Age, Length: 550068, dtype: int8

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].astype('category')
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].cat.codes
df['Stay_In_Current_City_Years']
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         4
#          ..
# 550063    1
# 550064    3
# 550065    4
# 550066    2
# 550067    4
# Name: Stay_In_Current_City_Years, Length: 550068, dtype: int8

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category',
#        'Purchase'],
#       dtype='object')

# %%
df.value_counts()
# Out:
# User_ID  Product_ID  Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 1000001  P00000142   0       0    10          0              2                           0               3                 13650       1
# 1004007  P00105342   1       3    12          0              1                           1               1                 11668       1
#          P00115942   1       3    12          0              1                           1               8                 9800        1
#          P00115142   1       3    12          0              1                           1               1                 11633       1
#          P00114942   1       3    12          0              1                           1               1                 19148       1
#                                                                                                                                       ..
# ...

# %%
df
# Out:
#         User_ID Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000001  P00069042       0    0          10              0
# 1       1000001  P00248942       0    0          10              0
# 2       1000001  P00087842       0    0          10              0
# 3       1000001  P00085442       0    0          10              0
# 4       1000002  P00285442       1    6          16              2
# ...         ...        ...     ...  ...         ...            ...
# 550063  1006033  P00372445       1    5          13              1
# 550064  1006035  P00375436       0    2           1              2
# 550065  1006036  P00375436       0    2          15              1
# 550066  1006038  P00375436       0    6           1              2
# 550067  1006039  P00371644       0    4           0              1
#
#         Stay_In_Current_City_Years  Marital_Status Product_Category  Purchase
# 0                                2               0                3      8370
# ...

# %%
# %%time
heatmaps_columns=['Gender','Age','Occupation','City_Category','Stay_In_Current_City_Years','Marital_Status','Product_Category','Purchase']
df_heatmaps=df[heatmaps_columns]
sns.heatmap(df_heatmaps.corr() , cmap='Pastel1')
# Out:
# CPU times: total: 250 ms
# Wall time: 231 ms
# <Axes: >

# %%
# %%time
sns.pairplot(df_heatmaps)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# checking whether data has null(missing) values

# %%
data.isnull().sum()
# data has no null values
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category              0
# Purchase                      0
# dtype: int64

# %%
# Checking the outliers

# %%
sns.boxplot(x='Gender', y='Purchase', data= data)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.boxplot(data=data['Occupation'])
plt.show()

# %%
sns.boxplot(data=data['Purchase'])
plt.show()

# %%
sns.boxplot(x='Marital_Status', y='Purchase', data= data)
plt.show()

# %%
sns.boxplot(x='Age', y='Purchase', data= data)
plt.show()

# %%
## RANGE OF ATTRIBUTES
# Range of Gender - M or F
# Range of Age - 0 to 55+
# Range of Occupation - 0 to 20
# Range of City_Category - A, B, C
# Range of Stay_In_Current_City_Years- 0 to $+
# Range of Marital_Status - 0 or 1
# Range of Product_Category - 1 to 20
# Range of Purchase - 12 to 23961

# %%
## RELATIONSHIP BETWEEN DIFFERENT COLUMNS

# %%
# Gender vs Purchase
# We can see that Males spend more than Females(in total)

# %%
sns.barplot(x='Gender', y='Purchase', data= data  , estimator = sum)
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='Gender', ylabel='Purchase'>

# %%
# Gender vs Stay_In_Current_City_Years
# Males tend to stay longer in a particular type of city

# %%
sns.countplot(x='Stay_In_Current_City_Years', hue='Gender', data= data)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Age vs Stay_In_Current_City_Years
# People in age 26-35 group stay in the same city more than others

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Age', data= data)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Age vs Purchase

# %%
sns.countplot(x='Age',hue='Purchase', data= data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 sns.countplot(x='Age',hue='Purchase', data= data)
#       2 plt.show()
#
# File ~\Newfolder\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\Newfolder\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\Newfolder\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
# ...

# %%
# Age vs Product_Category

# %%
sns.countplot(x= 'Product_Category' ,hue='Age', data= data)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Marital_Status vs Stay_In_Current_City_Years

# %%
sns.countplot(x='Stay_In_Current_City_Years', hue= 'Marital_Status',  data= data)
plt.legend(title='Marital_Status')
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Marital_Status vs Purchase

# %%
sns.barplot(x='Marital_Status', y = 'Purchase', data= data , estimator = sum)
plt.show()

# %%
# City_Category vs Purchase
# City_Category Type B spends the most amount of Money and Type C the least

# %%
sns.barplot(x='City_Category' , y='Purchase', data= data , estimator = sum )
plt.show()

# %%
# Occupation vs Purchase

# %%
sns.barplot(x='Occupation' , y='Purchase', data= data , estimator = sum )
plt.show()

# %%
sns.barplot(x='Occupation' , y='Purchase', data= data )
plt.show()

# %% [markdown]
# __MALE VS FEMALE__

# %%
## Are women spending more money per transaction than men? Why or Why not?

# %%
male_amount= data[data['Gender']=='M']['Purchase'].sum()
male_amount
# Out:
# 3909580100

# %%
female_amount=data[data['Gender']=='F']['Purchase'].sum()
female_amount
# Out:
# 1186232642

# %%
data['Gender'].value_counts()
# Out:
# Gender
# M    414259
# F    135809
# Name: count, dtype: int64

# %%
per_transaction_amt_male=male_amount/414259
per_transaction_amt_male
# Out:
# 9437.526040472265

# %%
per_transaction_amt_female=female_amount/135809
per_transaction_amt_female
# Out:
# 8734.565765155476

# %%
## Just by looking at the amount spent by males and females per transaction , we can seee that males spend more than females
## but this is only for the data provided to us , for whole population we need to apply Central Limit Theorem and find the Confidence Intervak

# %%
male_amt=data[data['Gender']=='M']['Purchase']
male_amt
# Out:
# 4          7969
# 5         15227
# 6         19215
# 7         15854
# 8         15686
#           ...
# 550057       61
# 550058      121
# 550060      494
# 550062      473
# 550063      368
# Name: Purchase, Length: 414259, dtype: int64

# %%
female_amt=data[data['Gender']=='F']['Purchase']
female_amt
# Out:
# 0          8370
# 1         15200
# 2          1422
# 3          1057
# 14         5378
#           ...
# 550061      599
# 550064      371
# 550065      137
# 550066      365
# 550067      490
# Name: Purchase, Length: 135809, dtype: int64

# %%
sns.histplot(data=male_amt ,kde = True )
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data=female_amt ,kde = True )
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
## From above two plots we can see that the spending pattern of both the males and females are similiar 
## so we can't say that one gender spends more than the other
## to prove that we apply CENTRAL LIMIT THEOREM

# %%
## Applying Central Limit Theorem

# %%
## taking sample size of 500

# %%
data.sample(500).groupby('Gender')['Purchase'].describe()
# Out:
# C:\Users\Jalaj\AppData\Local\Temp\ipykernel_32596\416129965.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.sample(500).groupby('Gender')['Purchase'].describe()
#         count         mean          std   min      25%     50%       75%  \
# Gender
# F       114.0  9182.701754  5111.915293  13.0  5924.75  8051.5  11644.75
# M       386.0  9055.142487  5071.142274  24.0  5535.25  8048.0  11981.00
#
#             max
# Gender
# F       23904.0
# M       23315.0

# %%
data.sample(500).groupby('Gender')['Purchase'].describe()
# Out:
# C:\Users\Jalaj\AppData\Local\Temp\ipykernel_32596\416129965.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.sample(500).groupby('Gender')['Purchase'].describe()
#         count         mean          std    min     25%     50%      75%  \
# Gender
# F       135.0  9000.288889  4672.542251  375.0  5705.5  7882.0  11705.5
# M       365.0  9546.413699  4907.919455   13.0  6118.0  8140.0  12090.0
#
#             max
# Gender
# F       23368.0
# M       23535.0

# %%
data.sample(500).groupby('Gender')['Purchase'].describe()
# Out:
# C:\Users\Jalaj\AppData\Local\Temp\ipykernel_32596\416129965.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.sample(500).groupby('Gender')['Purchase'].describe()
#         count         mean          std    min      25%     50%      75%  \
# Gender
# F       114.0  9102.307018  4663.032321  240.0  6123.00  8584.5  11933.5
# M       386.0  8982.764249  5169.379433  583.0  5392.75  7911.5  11863.0
#
#             max
# Gender
# F       20848.0
# M       23408.0

# %%
## taking different number of samples and iterations

# %%
# sample size = 500 , iterations = 1000

# %%
size=500
n = 1000

# %%
pd.set_option('display.max_rows', 20)
male_sample_mean1=[data[data['Gender']=='M'].sample(size)['Purchase'].mean() for i in range(n)]
male_sample_mean1
# Out:
# [9858.058,
#  9547.704,
#  9470.802,
#  8876.924,
#  9293.308,
#  9662.254,
#  9183.728,
#  9429.11,
#  9740.392,
#  9546.54,
#  9484.262,
#  9359.246,
#  9680.634,
#  9633.19,
#  9491.866,
#  9486.952,
#  9594.03,
#  9513.642,
#  9448.06,
#  9498.062,
#  9874.68,
#  9297.648,
#  8963.84,
#  9354.782,
#  9134.9,
#  9352.684,
#  9505.63,
#  9410.434,
#  9494.856,
#  9631.812,
#  9704.024,
#  9708.976,
#  9359.014,
#  9813.684,
#  9631.72,
#  9622.834,
#  9622.502,
#  8956.904,
#  9557.632,
#  9639.342,
#  9716.546,
#  9260.436,
#  9104.544,
#  9496.918,
#  9542.886,
#  9814.954,
#  9107.638,
#  9648.058,
#  9723.982,
#  9801.352,
#  9157.23,
#  10006.662,
#  8957.994,
#  9139.306,
#  9362.932,
#  9451.916,
#  9495.586,
#  9335.152,
#  9209.4,
#  9409.66,
#  9259.542,
#  9443.682,
#  9434.488,
#  9373.668,
#  9610.834,
#  9772.236,
#  9498.754,
#  8910.54,
#  9661.106,
#  9138.714,
#  9763.468,
#  9522.552,
#  9749.404,
#  9337.538,
#  9405.362,
#  9481.29,
#  8822.36,
#  9332.9,
# ...

# %%
female_sample_mean1=[data[data['Gender']=='F'].sample(size)['Purchase'].mean() for i in range(n)]
female_sample_mean1
# Out:
# [8885.514,
#  8565.336,
#  8612.634,
#  8778.064,
#  8607.768,
#  8695.48,
#  8731.432,
#  8737.582,
#  8780.386,
#  8741.16,
#  8791.962,
#  8718.588,
#  8748.046,
#  8843.032,
#  8437.708,
#  8951.048,
#  9106.944,
#  8348.44,
#  8736.288,
#  8755.078,
#  8653.036,
#  8990.81,
#  8457.312,
#  8848.896,
#  8732.106,
#  8651.144,
#  8585.826,
#  8740.064,
#  8772.484,
#  8893.146,
#  8787.014,
#  8848.702,
#  8891.044,
#  8850.54,
#  8492.15,
#  8461.756,
#  8695.886,
#  8643.736,
#  8778.686,
#  9075.194,
#  8700.796,
#  8763.956,
#  9323.22,
#  8344.696,
#  8349.132,
#  8745.974,
#  8719.588,
#  8456.54,
#  8798.102,
#  8446.314,
#  8561.866,
#  8791.032,
#  8546.77,
#  8384.702,
#  8802.77,
#  8872.478,
#  8612.842,
#  8647.05,
#  9276.35,
#  8741.244,
#  8759.138,
#  8707.158,
#  9009.04,
#  8513.26,
#  8620.412,
#  8795.834,
#  8557.884,
#  8623.48,
#  8891.248,
#  8344.338,
#  8852.588,
#  8571.532,
#  8558.602,
#  8416.618,
#  8686.586,
#  8747.62,
#  8911.758,
#  8933.874,
# ...

# %%
sns.histplot(male_sample_mean1, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(female_sample_mean1,kde=True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
male_95_confiedence_interval11 = np.percentile(male_sample_mean1, [2.5, 97.5])
male_95_confiedence_interval11
# Out:
# array([8982.6425 , 9872.39425])

# %%
male_99_confiedence_interval12 = np.percentile(male_sample_mean1, [0.5, 99.5])
male_99_confiedence_interval12
# Out:
# array([ 8899.22503, 10020.03519])

# %%
female_95_confiedence_interval21 = np.percentile(female_sample_mean1, [2.5, 97.5])
female_95_confiedence_interval21
# Out:
# array([8328.46015, 9143.66715])

# %%
female_99_confiedence_interval22 = np.percentile(female_sample_mean1, [0.5, 99.5])
female_99_confiedence_interval22
# Out:
# array([8192.29973, 9238.19253])

# %%
# sample size = 1000 , iterations = 2000

# %%
size=1000
n = 2000

# %%
male_sample_mean2=[data[data['Gender']=='M'].sample(size)['Purchase'].mean() for i in range(n)]
male_sample_mean2
# Out:
# [9481.356,
#  9491.379,
#  9544.917,
#  9442.148,
#  9315.522,
#  9342.446,
#  9329.026,
#  9364.269,
#  9836.887,
#  9519.919,
#  9470.677,
#  9397.595,
#  9454.112,
#  9496.363,
#  9318.501,
#  9580.206,
#  9693.536,
#  9683.524,
#  9552.285,
#  9573.281,
#  9211.79,
#  9243.55,
#  9340.973,
#  8973.351,
#  9570.601,
#  9426.932,
#  9371.672,
#  9328.229,
#  9409.742,
#  9481.28,
#  9289.841,
#  9614.484,
#  9534.571,
#  9538.573,
#  9470.033,
#  9374.17,
#  9571.932,
#  9292.951,
#  9531.631,
#  9561.859,
#  9301.606,
#  9364.559,
#  9411.231,
#  9440.31,
#  9583.25,
#  9113.316,
#  9640.396,
#  9535.841,
#  9220.556,
#  9394.543,
#  9273.121,
#  9672.696,
#  9352.433,
#  9251.364,
#  9396.765,
#  9334.35,
#  9450.788,
#  9449.019,
#  9575.347,
#  9431.111,
#  9440.709,
#  9140.51,
#  9648.696,
#  9281.389,
#  9246.658,
#  9500.511,
#  9343.041,
#  9217.391,
#  9208.023,
#  9601.221,
#  9352.856,
#  9339.252,
#  9431.147,
#  9290.646,
#  9164.422,
#  9552.455,
#  9408.19,
# ...

# %%
female_sample_mean2=[data[data['Gender']=='F'].sample(size)['Purchase'].mean() for i in range(n)]
male_sample_mean2
# Out:
# [9481.356,
#  9491.379,
#  9544.917,
#  9442.148,
#  9315.522,
#  9342.446,
#  9329.026,
#  9364.269,
#  9836.887,
#  9519.919,
#  9470.677,
#  9397.595,
#  9454.112,
#  9496.363,
#  9318.501,
#  9580.206,
#  9693.536,
#  9683.524,
#  9552.285,
#  9573.281,
#  9211.79,
#  9243.55,
#  9340.973,
#  8973.351,
#  9570.601,
#  9426.932,
#  9371.672,
#  9328.229,
#  9409.742,
#  9481.28,
#  9289.841,
#  9614.484,
#  9534.571,
#  9538.573,
#  9470.033,
#  9374.17,
#  9571.932,
#  9292.951,
#  9531.631,
#  9561.859,
#  9301.606,
#  9364.559,
#  9411.231,
#  9440.31,
#  9583.25,
#  9113.316,
#  9640.396,
#  9535.841,
#  9220.556,
#  9394.543,
#  9273.121,
#  9672.696,
#  9352.433,
#  9251.364,
#  9396.765,
#  9334.35,
#  9450.788,
#  9449.019,
#  9575.347,
#  9431.111,
#  9440.709,
#  9140.51,
#  9648.696,
#  9281.389,
#  9246.658,
#  9500.511,
#  9343.041,
#  9217.391,
#  9208.023,
#  9601.221,
#  9352.856,
#  9339.252,
#  9431.147,
#  9290.646,
#  9164.422,
#  9552.455,
#  9408.19,
# ...

# %%
sns.histplot(male_sample_mean2, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(female_sample_mean2,kde=True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
male_95_confiedence_interval13 = np.percentile(male_sample_mean2, [2.5, 97.5])
male_95_confiedence_interval13
# Out:
# array([9133.42505, 9758.4149 ])

# %%
male_99_confiedence_interval14 = np.percentile(male_sample_mean2, [0.5, 99.5])
male_99_confiedence_interval14
# Out:
# array([9023.44171, 9870.51088])

# %%
female_95_confiedence_interval23 = np.percentile(female_sample_mean2, [2.5, 97.5])
female_95_confiedence_interval23
# Out:
# array([8437.14995 , 9030.830675])

# %%
female_99_confiedence_interval24 = np.percentile(female_sample_mean2, [0.5, 99.5])
female_99_confiedence_interval24
# Out:
# array([8352.5925  , 9115.809075])

# %%
# sample size = 2000 , iterations = 5000

# %%
size=2000
n = 5000

# %%
male_sample_mean3=[data[data['Gender']=='M'].sample(size)['Purchase'].mean() for i in range(n)]
male_sample_mean3
# Out:
# [9619.3665,
#  9542.448,
#  9514.14,
#  9377.022,
#  9286.4875,
#  9400.7955,
#  9465.5425,
#  9275.4255,
#  9340.192,
#  9403.9615,
#  9215.369,
#  9485.0785,
#  9415.559,
#  9626.2195,
#  9320.9055,
#  9512.216,
#  9391.2545,
#  9693.6625,
#  9359.941,
#  9168.016,
#  9520.896,
#  9487.08,
#  9365.2195,
#  9347.8655,
#  9692.765,
#  9451.6,
#  9486.5065,
#  9405.8085,
#  9205.9935,
#  9349.697,
#  9222.2055,
#  9189.154,
#  9704.1255,
#  9539.4155,
#  9821.9305,
#  9523.8255,
#  9414.872,
#  9479.6855,
#  9474.197,
#  9474.025,
#  9574.0105,
#  9394.8515,
#  9262.0035,
#  9450.4105,
#  9475.9845,
#  9491.546,
#  9371.2305,
#  9311.5355,
#  9479.663,
#  9519.89,
#  9484.8945,
#  9429.706,
#  9315.4795,
#  9414.906,
#  9390.0905,
#  9396.9835,
#  9490.036,
#  9503.7925,
#  9394.338,
#  9522.1455,
#  9492.2695,
#  9280.0185,
#  9191.063,
#  9595.442,
#  9625.584,
#  9594.781,
#  9371.988,
#  9392.3935,
#  9329.1785,
#  9578.6785,
#  9606.7825,
#  9690.02,
#  9465.9465,
#  9275.5575,
# ...

# %%
female_sample_mean3=[data[data['Gender']=='F'].sample(size)['Purchase'].mean() for i in range(n)]
male_sample_mean3
# Out:
# [9619.3665,
#  9542.448,
#  9514.14,
#  9377.022,
#  9286.4875,
#  9400.7955,
#  9465.5425,
#  9275.4255,
#  9340.192,
#  9403.9615,
#  9215.369,
#  9485.0785,
#  9415.559,
#  9626.2195,
#  9320.9055,
#  9512.216,
#  9391.2545,
#  9693.6625,
#  9359.941,
#  9168.016,
#  9520.896,
#  9487.08,
#  9365.2195,
#  9347.8655,
#  9692.765,
#  9451.6,
#  9486.5065,
#  9405.8085,
#  9205.9935,
#  9349.697,
#  9222.2055,
#  9189.154,
#  9704.1255,
#  9539.4155,
#  9821.9305,
#  9523.8255,
#  9414.872,
#  9479.6855,
#  9474.197,
#  9474.025,
#  9574.0105,
#  9394.8515,
#  9262.0035,
#  9450.4105,
#  9475.9845,
#  9491.546,
#  9371.2305,
#  9311.5355,
#  9479.663,
#  9519.89,
#  9484.8945,
#  9429.706,
#  9315.4795,
#  9414.906,
#  9390.0905,
#  9396.9835,
#  9490.036,
#  9503.7925,
#  9394.338,
#  9522.1455,
#  9492.2695,
#  9280.0185,
#  9191.063,
#  9595.442,
#  9625.584,
#  9594.781,
#  9371.988,
#  9392.3935,
#  9329.1785,
#  9578.6785,
#  9606.7825,
#  9690.02,
#  9465.9465,
#  9275.5575,
# ...

# %%
sns.histplot(male_sample_mean3, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(female_sample_mean3,kde=True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
male_95_confiedence_interval15 = np.percentile(male_sample_mean3, [2.5, 97.5])
male_95_confiedence_interval15
# Out:
# array([9208.5857625, 9663.272375 ])

# %%
male_99_confiedence_interval16 = np.percentile(male_sample_mean3, [0.5, 99.5])
male_99_confiedence_interval16
# Out:
# array([9140.4485025, 9736.1935825])

# %%
female_95_confiedence_interval25 = np.percentile(female_sample_mean3, [2.5, 97.5])
female_95_confiedence_interval25
# Out:
# array([8528.762225 , 8945.0866625])

# %%
female_99_confiedence_interval26 = np.percentile(female_sample_mean3, [0.5, 99.5])
female_99_confiedence_interval26
# Out:
# array([8463.9651425, 9007.3839225])

# %%
## Male 95% Confidence Interval
print(f"1. {male_95_confiedence_interval11}")
print(f"2. {male_95_confiedence_interval13}")
print(f"3. {male_95_confiedence_interval15}")
# Out:
# 1. [8982.6425  9872.39425]
# 2. [9133.42505 9758.4149 ]
# 3. [9208.5857625 9663.272375 ]

# %%
## Male 99% Confidence Interval
print(f"1. {male_99_confiedence_interval12}")
print(f"2. {male_99_confiedence_interval14}")
print(f"3. {male_99_confiedence_interval16}")
# Out:
# 1. [ 8899.22503 10020.03519]
# 2. [9023.44171 9870.51088]
# 3. [9140.4485025 9736.1935825]

# %%
## Female 95% Confidence Interval
print(f"1. {female_95_confiedence_interval21}")
print(f"2. {female_95_confiedence_interval23}")
print(f"3. {female_95_confiedence_interval25}")
# Out:
# 1. [8328.46015 9143.66715]
# 2. [8437.14995  9030.830675]
# 3. [8528.762225  8945.0866625]

# %%
## Female 99% Confidence Interval
print(f"1. {female_99_confiedence_interval22}")
print(f"2. {female_99_confiedence_interval24}")
print(f"3. {female_99_confiedence_interval26}")
# Out:
# 1. [8192.29973 9238.19253]
# 2. [8352.5925   9115.809075]
# 3. [8463.9651425 9007.3839225]

# %%
## means of both male and females are NORMALLY DISTRIBUTED (bell shaped)

# %%
# We can see that both the CI's i.e. 95% and 99% overlap  , so we can't say that Females are spending more or vice versa

# %%
#  Walmart can leverage the above outcome by focusing on personlized offers based on spending behaviours and not based on gender ,
# this will help walmart save resourse

# %% [markdown]
# __MARRIED VS UNMARRIED__

# %%
# sample size = 500 , iterations = 1000

# %%
size=500
n = 1000

# %%
married_sample_mean1=[data[data['Marital_Status']=='1'].sample(size)['Purchase'].mean() for i in range(n)]
married_sample_mean1
# Out:
# [9271.804,
#  8982.786,
#  9091.8,
#  9266.562,
#  9361.004,
#  9355.158,
#  9461.192,
#  9384.544,
#  9018.658,
#  8791.56,
#  9129.846,
#  9089.362,
#  8986.464,
#  9609.236,
#  9359.256,
#  9368.552,
#  9343.034,
#  9370.912,
#  9153.298,
#  9384.784,
#  9408.63,
#  9346.84,
#  9326.032,
#  9066.126,
#  9697.624,
#  8706.618,
#  9270.734,
#  9318.4,
#  9179.44,
#  9657.746,
#  9070.942,
#  9052.28,
#  8797.374,
#  9692.602,
#  9471.344,
#  9028.298,
#  9475.636,
#  9147.728,
#  9471.812,
#  9115.404,
#  9410.882,
#  8961.936,
#  9667.012,
#  8966.868,
#  9476.526,
#  9286.328,
#  9180.144,
#  9735.558,
#  9463.676,
#  9292.55,
#  9546.352,
#  9237.732,
#  9200.39,
#  8959.882,
#  8981.88,
#  9160.334,
#  8913.48,
#  9157.424,
#  9478.926,
#  9152.334,
#  9257.38,
#  9273.882,
#  9405.292,
#  9187.976,
#  9172.364,
#  9568.872,
#  9494.886,
#  9478.774,
#  8982.828,
#  9504.794,
#  9350.978,
#  9249.052,
#  9440.184,
#  9034.426,
#  9131.062,
#  9158.746,
#  9205.2,
#  9322.352,
# ...

# %%
unmarried_sample_mean1=[data[data['Marital_Status']=='0'].sample(size)['Purchase'].mean() for i in range(n)]
unmarried_sample_mean1
# Out:
# [9243.592,
#  9824.578,
#  9302.218,
#  9642.746,
#  9335.624,
#  9563.874,
#  9767.114,
#  9474.328,
#  9055.444,
#  9319.216,
#  9063.778,
#  9259.19,
#  9295.788,
#  9021.77,
#  9430.91,
#  9103.982,
#  9276.03,
#  9300.93,
#  9133.742,
#  9730.54,
#  9107.074,
#  9074.77,
#  9049.99,
#  9161.344,
#  9451.742,
#  9169.416,
#  9255.928,
#  9336.756,
#  8955.474,
#  9356.766,
#  9577.574,
#  8983.268,
#  9108.144,
#  8962.886,
#  9623.722,
#  9209.89,
#  9513.982,
#  9371.474,
#  9087.024,
#  8998.84,
#  8973.726,
#  9230.458,
#  9057.284,
#  9640.762,
#  9091.982,
#  9763.9,
#  9244.214,
#  9333.192,
#  9541.434,
#  9353.236,
#  9651.744,
#  9804.008,
#  9257.178,
#  9551.548,
#  9617.706,
#  9264.35,
#  9242.566,
#  9150.756,
#  9004.428,
#  9273.166,
#  9604.606,
#  9120.22,
#  9597.738,
#  9176.9,
#  9259.668,
#  9504.476,
#  9306.502,
#  9466.5,
#  9463.43,
#  9271.048,
#  9382.564,
#  9462.356,
#  9479.514,
#  9213.152,
#  8804.158,
#  8736.058,
#  9796.206,
#  9441.568,
# ...

# %%
sns.histplot(married_sample_mean1, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(unmarried_sample_mean1, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
married_95_confiedence_interval11 = np.percentile(married_sample_mean1, [2.5, 97.5])
married_95_confiedence_interval11
# Out:
# array([8844.0723 , 9661.43895])

# %%
married_99_confiedence_interval12 = np.percentile(married_sample_mean1, [2.5, 97.5])
married_99_confiedence_interval12
# Out:
# array([8844.0723 , 9661.43895])

# %%
unmarried_95_confiedence_interval21 = np.percentile(unmarried_sample_mean1, [2.5, 97.5])
unmarried_95_confiedence_interval21
# Out:
# array([8844.915 , 9719.2766])

# %%
unmarried_99_confiedence_interval22 = np.percentile(unmarried_sample_mean1, [2.5, 97.5])
unmarried_99_confiedence_interval22
# Out:
# array([8844.915 , 9719.2766])

# %%
# sample size = 1000 , iterations = 2000

# %%
size=1000
n = 2000

# %%
married_sample_mean2=[data[data['Marital_Status']=='1'].sample(size)['Purchase'].mean() for i in range(n)]
married_sample_mean2
# Out:
# [9089.318,
#  9370.759,
#  9393.818,
#  9007.182,
#  9145.597,
#  9152.771,
#  9497.718,
#  8776.866,
#  9331.957,
#  9142.041,
#  8972.052,
#  9318.725,
#  9523.285,
#  9307.344,
#  9136.862,
#  9374.741,
#  9440.191,
#  9481.842,
#  9252.2,
#  9255.094,
#  9438.586,
#  9268.737,
#  9361.264,
#  9226.995,
#  9345.568,
#  9105.961,
#  9379.666,
#  9363.592,
#  9101.046,
#  9226.197,
#  9365.76,
#  9383.752,
#  9290.254,
#  9236.377,
#  9133.622,
#  9047.506,
#  9374.276,
#  9350.586,
#  9077.275,
#  9274.985,
#  9468.209,
#  9727.709,
#  9121.697,
#  9299.253,
#  9006.724,
#  9199.092,
#  9187.174,
#  9401.585,
#  9284.708,
#  9253.304,
#  9441.248,
#  9454.02,
#  9244.341,
#  9172.2,
#  9338.19,
#  9495.186,
#  9234.341,
#  9304.108,
#  9174.967,
#  9430.986,
#  9027.405,
#  8873.346,
#  9331.205,
#  9557.232,
#  8810.77,
#  9293.035,
#  9340.543,
#  9126.739,
#  9163.548,
#  9239.334,
#  8976.545,
#  8955.369,
#  9165.207,
#  9517.532,
#  9206.273,
#  9396.224,
#  9044.718,
# ...

# %%
unmarried_sample_mean2=[data[data['Marital_Status']=='0'].sample(size)['Purchase'].mean() for i in range(n)]
unmarried_sample_mean2
# Out:
# [9359.978,
#  9397.143,
#  9263.216,
#  9162.387,
#  9255.428,
#  9419.188,
#  9362.666,
#  9251.46,
#  9362.16,
#  9325.603,
#  9511.048,
#  9177.435,
#  9174.998,
#  9216.465,
#  8795.289,
#  8945.884,
#  9192.868,
#  9475.75,
#  9271.884,
#  9263.871,
#  9223.771,
#  9308.754,
#  9294.278,
#  9275.04,
#  9209.078,
#  9229.361,
#  9284.306,
#  9258.721,
#  9300.343,
#  9483.161,
#  8965.832,
#  9370.707,
#  9428.713,
#  9248.49,
#  9204.358,
#  9147.674,
#  9024.175,
#  9374.002,
#  9213.176,
#  8999.661,
#  9245.963,
#  9193.195,
#  9516.15,
#  9359.095,
#  9265.134,
#  9423.749,
#  9588.398,
#  9157.666,
#  9057.414,
#  9099.675,
#  9165.092,
#  9234.04,
#  9238.089,
#  9218.561,
#  9199.772,
#  9375.332,
#  9295.204,
#  9158.699,
#  9388.016,
#  9194.417,
#  9425.53,
#  9421.383,
#  9211.182,
#  9389.907,
#  9251.404,
#  9427.164,
#  9546.485,
#  9438.365,
#  9599.627,
#  9599.824,
#  9458.442,
#  9371.562,
#  8895.327,
#  9114.177,
#  9393.305,
#  9530.315,
#  9388.824,
# ...

# %%
sns.histplot(married_sample_mean2, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(unmarried_sample_mean2, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
married_95_confiedence_interval13 = np.percentile(married_sample_mean2, [2.5, 97.5])
married_95_confiedence_interval13
# Out:
# array([8932.709425, 9559.83905 ])

# %%
married_99_confiedence_interval14 = np.percentile(married_sample_mean2, [0.5, 99.5])
married_99_confiedence_interval14
# Out:
# array([8812.75995, 9674.5673 ])

# %%
unmarried_95_confiedence_interval23 = np.percentile(unmarried_sample_mean2, [2.5, 97.5])
unmarried_95_confiedence_interval23
# Out:
# array([8956.2631, 9578.7718])

# %%
unmarried_99_confiedence_interval24 = np.percentile(unmarried_sample_mean2, [0.5, 99.5])
unmarried_99_confiedence_interval24
# Out:
# array([8886.02522, 9686.26608])

# %%
# sample size = 2000 , iterations = 5000

# %%
size=2000
n = 5000

# %%
married_sample_mean3=[data[data['Marital_Status']=='1'].sample(size)['Purchase'].mean() for i in range(n)]
married_sample_mean3
# Out:
# [9324.4345,
#  8945.856,
#  9199.18,
#  9104.072,
#  9281.8355,
#  9083.006,
#  9120.7135,
#  9103.187,
#  8900.7,
#  9188.6755,
#  9240.8015,
#  9151.3785,
#  9497.898,
#  9385.1225,
#  9193.5845,
#  9168.105,
#  9038.956,
#  9244.2065,
#  9118.6065,
#  9232.8705,
#  9486.532,
#  9108.4945,
#  9198.384,
#  9289.3755,
#  9241.9905,
#  9258.176,
#  9260.8205,
#  9275.8635,
#  9225.0155,
#  9320.8165,
#  8952.003,
#  9215.795,
#  9430.112,
#  9276.3155,
#  9259.5425,
#  9360.3435,
#  9261.831,
#  9317.848,
#  9086.7975,
#  9292.41,
#  9236.3185,
#  9181.5855,
#  9270.962,
#  9315.848,
#  9275.532,
#  9237.659,
#  9414.665,
#  9559.1065,
#  9269.1015,
#  9224.73,
#  9130.0055,
#  9201.3765,
#  9086.796,
#  9242.889,
#  9205.4585,
#  9060.767,
#  9183.688,
#  9298.8505,
#  9296.82,
#  9501.238,
#  9135.202,
#  9283.33,
#  9332.598,
#  9502.361,
#  9142.7315,
#  9339.8295,
#  9331.167,
#  9324.7195,
#  9141.5335,
#  9327.5685,
#  9215.5465,
#  9283.342,
#  9200.7875,
#  9218.678,
# ...

# %%
unmarried_sample_mean3=[data[data['Marital_Status']=='0'].sample(size)['Purchase'].mean() for i in range(n)]
unmarried_sample_mean3
# Out:
# [9307.754,
#  9064.46,
#  9270.094,
#  9307.8885,
#  9264.0195,
#  9138.7565,
#  9209.029,
#  9203.8395,
#  9250.517,
#  9280.066,
#  9440.118,
#  9090.821,
#  9297.325,
#  9301.0655,
#  9370.5095,
#  9247.3985,
#  9262.236,
#  9020.262,
#  9203.9535,
#  9199.0315,
#  9265.027,
#  9243.7965,
#  9435.479,
#  9317.708,
#  9376.29,
#  9083.9975,
#  9165.9795,
#  9319.771,
#  9188.5425,
#  9292.887,
#  9142.938,
#  9207.711,
#  9289.068,
#  9233.8335,
#  9305.7715,
#  9110.843,
#  9305.194,
#  9078.4,
#  9415.8495,
#  9502.197,
#  9185.5635,
#  9297.249,
#  9272.4135,
#  9057.7105,
#  9295.797,
#  9352.4085,
#  9196.3065,
#  9183.738,
#  9175.2555,
#  9244.4995,
#  9286.674,
#  9246.354,
#  9302.503,
#  9051.28,
#  9311.589,
#  9408.0365,
#  9104.126,
#  9298.882,
#  9385.514,
#  9310.1455,
#  9219.51,
#  9218.3745,
#  9237.8835,
#  8867.3495,
#  9508.438,
#  9185.9975,
#  9192.135,
#  9051.9035,
#  9274.696,
#  9434.131,
#  9315.49,
#  9072.766,
#  9188.4655,
#  9376.1525,
#  9157.145,
# ...

# %%
sns.histplot(married_sample_mean3, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(unmarried_sample_mean3, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
married_95_confiedence_interval15 = np.percentile(married_sample_mean3, [2.5, 97.5])
married_95_confiedence_interval15
# Out:
# array([9036.41295, 9481.91535])

# %%
married_99_confiedence_interval16 = np.percentile(married_sample_mean3, [0.5, 99.5])
married_99_confiedence_interval16
# Out:
# array([8965.0359075, 9550.930255 ])

# %%
unmarried_95_confiedence_interval25 = np.percentile(unmarried_sample_mean3, [2.5, 97.5])
unmarried_95_confiedence_interval25
# Out:
# array([9042.021875 , 9491.0196125])

# %%
unmarried_99_confiedence_interval26 = np.percentile(unmarried_sample_mean3, [0.5, 99.5])
unmarried_99_confiedence_interval26
# Out:
# array([8972.55962  , 9566.2465925])

# %%
## Married 95% Confidence Interval
print(f"1. {married_95_confiedence_interval11}")
print(f"2. {married_95_confiedence_interval13}")
print(f"3. {married_95_confiedence_interval15}")
# Out:
# 1. [8844.0723  9661.43895]
# 2. [8932.709425 9559.83905 ]
# 3. [9036.41295 9481.91535]

# %%
## Married 99% Confidence Interval
print(f"1. {married_99_confiedence_interval12}")
print(f"2. {married_99_confiedence_interval14}")
print(f"3. {married_99_confiedence_interval16}")
# Out:
# 1. [8844.0723  9661.43895]
# 2. [8812.75995 9674.5673 ]
# 3. [8965.0359075 9550.930255 ]

# %%
## Unmarried 95% Confidence Interval
print(f"1. {unmarried_95_confiedence_interval21}")
print(f"2. {unmarried_95_confiedence_interval23}")
print(f"3. {unmarried_95_confiedence_interval25}")
# Out:
# 1. [8844.915  9719.2766]
# 2. [8956.2631 9578.7718]
# 3. [9042.021875  9491.0196125]

# %%
## Unmarried 99% Confidence Interval
print(f"1. {unmarried_99_confiedence_interval22}")
print(f"2. {unmarried_99_confiedence_interval24}")
print(f"3. {unmarried_99_confiedence_interval26}")
# Out:
# 1. [8844.915  9719.2766]
# 2. [8886.02522 9686.26608]
# 3. [8972.55962   9566.2465925]

# %%
# same as male vs female , we can see that here also both the confidence intervals are overlapping, 
# so we can not say that married or unmarried spend more amount

# %% [markdown]
# __AGE__

# %%
data['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
data['Age'].value_counts()
# Out:
# Age
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: count, dtype: int64

# %%
data.groupby('Age')['Purchase'].sum()
# Out:
# Age
# 0-17      134913183
# 18-25     913848675
# 26-35    2031770578
# 36-45    1026569884
# 46-50     420843403
# 51-55     367099644
# 55+       200767375
# Name: Purchase, dtype: int64

# %%
134913183/15102
# Out:
# 8933.464640444974

# %%
size=200
n = 1000

# %%
age_sample_mean1=[data[data['Age']=='0-17'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean1
# Out:
# [8537.39,
#  8542.81,
#  9796.965,
#  9441.26,
#  8914.955,
#  8414.965,
#  9219.465,
#  8410.815,
#  9093.895,
#  8827.0,
#  8738.545,
#  9157.99,
#  9211.525,
#  7960.545,
#  8555.915,
#  8634.425,
#  7948.465,
#  8755.6,
#  9143.395,
#  8618.56,
#  9025.17,
#  9143.58,
#  9175.57,
#  8614.31,
#  9828.13,
#  9054.66,
#  9531.375,
#  8928.435,
#  9283.745,
#  8730.93,
#  9047.785,
#  9643.435,
#  8761.555,
#  9259.54,
#  9109.41,
#  9607.975,
#  9450.905,
#  9286.385,
#  9109.48,
#  9674.87,
#  9000.89,
#  9483.385,
#  8592.365,
#  8618.56,
#  8952.98,
#  9224.845,
#  9014.33,
#  8637.615,
#  9583.025,
#  8255.585,
#  8325.415,
#  9039.08,
#  8726.945,
#  9176.355,
#  9147.255,
#  8415.27,
#  8084.645,
#  9129.82,
#  8603.525,
#  9147.64,
#  9315.43,
#  9128.015,
#  8835.535,
#  8987.52,
#  8817.14,
#  8601.95,
#  8592.905,
#  8643.165,
#  9153.71,
#  8965.71,
#  8450.96,
#  8820.165,
#  8915.2,
#  8995.705,
#  8376.255,
#  8721.04,
#  9444.135,
#  9051.31,
#  8877.925,
#  9043.87,
# ...

# %%
age_sample_mean2=[data[data['Age']=='18-25'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean2
# Out:
# [8985.23,
#  9342.745,
#  9357.515,
#  9265.605,
#  9772.07,
#  9271.465,
#  9151.815,
#  9343.095,
#  9108.125,
#  9039.915,
#  8931.715,
#  8903.52,
#  8900.59,
#  9289.95,
#  9004.03,
#  8979.62,
#  8921.435,
#  9385.125,
#  9676.945,
#  9141.87,
#  9143.08,
#  8952.18,
#  8757.74,
#  8901.635,
#  9550.825,
#  9152.585,
#  8855.84,
#  8665.575,
#  9541.545,
#  9058.46,
#  9255.955,
#  9137.74,
#  10067.195,
#  9019.41,
#  9207.835,
#  9328.535,
#  9729.95,
#  9361.855,
#  8672.155,
#  9538.245,
#  9295.82,
#  8695.465,
#  9486.265,
#  8992.23,
#  9239.155,
#  9200.3,
#  9188.07,
#  9066.645,
#  9111.315,
#  8673.395,
#  9492.425,
#  9361.575,
#  9457.5,
#  8582.895,
#  9180.48,
#  8998.755,
#  9918.565,
#  9253.05,
#  9118.945,
#  9443.625,
#  9061.9,
#  9753.41,
#  8916.525,
#  9138.855,
#  8991.645,
#  9182.815,
#  9316.155,
#  9952.71,
#  9157.595,
#  8948.595,
#  8742.755,
#  9281.34,
#  9238.235,
#  9330.015,
#  8698.78,
#  8934.515,
#  9505.88,
#  9118.105,
#  8813.105,
# ...

# %%
age_sample_mean3=[data[data['Age']=='26-35'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean3
# Out:
# [8964.96,
#  9369.405,
#  9209.08,
#  8688.785,
#  9532.855,
#  9334.76,
#  9906.175,
#  9317.115,
#  9408.215,
#  9427.91,
#  9523.81,
#  9515.48,
#  9841.72,
#  8957.405,
#  9091.5,
#  8940.82,
#  9494.605,
#  9134.245,
#  9575.42,
#  9879.96,
#  9138.885,
#  8810.47,
#  9316.005,
#  9394.265,
#  9421.035,
#  9293.385,
#  8907.635,
#  8920.11,
#  9598.82,
#  9477.86,
#  9437.835,
#  10008.23,
#  8874.88,
#  9441.79,
#  9310.595,
#  8384.25,
#  9299.0,
#  9046.985,
#  9042.06,
#  9524.945,
#  8799.91,
#  9773.93,
#  8976.295,
#  9109.585,
#  8549.02,
#  8925.185,
#  9300.04,
#  8773.465,
#  9381.415,
#  9438.31,
#  9462.33,
#  8866.62,
#  9095.52,
#  10173.065,
#  8994.595,
#  9928.435,
#  9030.245,
#  9589.315,
#  9403.22,
#  9178.225,
#  9511.075,
#  8471.035,
#  9731.115,
#  9395.255,
#  9565.475,
#  9211.95,
#  9628.805,
#  8756.53,
#  8854.075,
#  9277.29,
#  8880.7,
#  8729.06,
#  9590.415,
#  9070.345,
#  9277.34,
#  9712.06,
#  9025.935,
#  9433.61,
#  9466.2,
#  9840.385,
# ...

# %%
age_sample_mean4=[data[data['Age']=='36-45'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean4
# Out:
# [9762.045,
#  9559.25,
#  9269.675,
#  9114.61,
#  9208.77,
#  8894.14,
#  8884.0,
#  8893.345,
#  8351.105,
#  9863.135,
#  8522.78,
#  8938.495,
#  9245.84,
#  9380.365,
#  9004.14,
#  9711.415,
#  9686.455,
#  9641.45,
#  9593.615,
#  9357.17,
#  9417.575,
#  9652.355,
#  9694.69,
#  9443.61,
#  9367.1,
#  9081.65,
#  9541.44,
#  10070.375,
#  8764.085,
#  9619.215,
#  9389.815,
#  9464.355,
#  9452.515,
#  8887.305,
#  9197.51,
#  8751.775,
#  9084.44,
#  9498.375,
#  9136.82,
#  9663.205,
#  9159.2,
#  8594.425,
#  9103.855,
#  9232.495,
#  8981.095,
#  9318.47,
#  9539.57,
#  8853.085,
#  9835.005,
#  8822.26,
#  9481.305,
#  9170.945,
#  9121.325,
#  9383.22,
#  9548.67,
#  9238.345,
#  8976.805,
#  9084.42,
#  9012.03,
#  9070.875,
#  9469.245,
#  9609.725,
#  9874.96,
#  9086.25,
#  9575.715,
#  9435.045,
#  9421.255,
#  9402.705,
#  9190.075,
#  9635.305,
#  9238.585,
#  9122.645,
#  9142.41,
#  9046.865,
#  9200.685,
#  8890.6,
#  9935.775,
#  9103.94,
#  9569.18,
# ...

# %%
age_sample_mean5=[data[data['Age']=='46-50'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean5
# Out:
# [9424.475,
#  9544.565,
#  9089.215,
#  9065.995,
#  8727.85,
#  8530.43,
#  8780.49,
#  9662.475,
#  8807.215,
#  8871.615,
#  9775.555,
#  9300.135,
#  9350.45,
#  9403.195,
#  9144.14,
#  9682.77,
#  9631.105,
#  8699.305,
#  8974.0,
#  9197.4,
#  9501.815,
#  8742.15,
#  9108.895,
#  8843.815,
#  8804.67,
#  8570.65,
#  9578.89,
#  9203.455,
#  8688.47,
#  9247.03,
#  9293.34,
#  9421.89,
#  10102.66,
#  8731.81,
#  9146.9,
#  9712.86,
#  8711.155,
#  9154.325,
#  9715.7,
#  9125.38,
#  9314.195,
#  9832.485,
#  9140.005,
#  8349.07,
#  9259.15,
#  9493.48,
#  9698.11,
#  9081.325,
#  9352.71,
#  9063.495,
#  8804.9,
#  9395.085,
#  9580.335,
#  8955.715,
#  9330.915,
#  8869.75,
#  9283.625,
#  9052.945,
#  8862.435,
#  9687.055,
#  8876.04,
#  9332.39,
#  9221.34,
#  9422.875,
#  9765.125,
#  9654.66,
#  9197.24,
#  9361.92,
#  9294.38,
#  9745.605,
#  9131.65,
#  8621.06,
#  9342.29,
#  9160.16,
#  9203.91,
#  9218.41,
#  8880.5,
#  9650.01,
#  8476.055,
#  8831.675,
# ...

# %%
age_sample_mean6=[data[data['Age']=='51-55'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean6
# Out:
# [8958.7,
#  9521.465,
#  10364.69,
#  9277.125,
#  9369.315,
#  9587.41,
#  9327.82,
#  9302.78,
#  9365.245,
#  9544.01,
#  9756.13,
#  9061.82,
#  10345.55,
#  9482.13,
#  9862.895,
#  9520.075,
#  9935.935,
#  9321.065,
#  9893.005,
#  9441.42,
#  9832.59,
#  9831.635,
#  9042.225,
#  9499.855,
#  9070.035,
#  9053.435,
#  9089.38,
#  9449.065,
#  9292.02,
#  9434.56,
#  9919.895,
#  8881.095,
#  9840.215,
#  10090.67,
#  9913.79,
#  10216.72,
#  9595.325,
#  9708.515,
#  9749.665,
#  9130.11,
#  9567.385,
#  8885.43,
#  9827.14,
#  9436.935,
#  9575.595,
#  9674.975,
#  9466.38,
#  9410.74,
#  9810.325,
#  9213.955,
#  9573.43,
#  9819.415,
#  10090.295,
#  10095.305,
#  10114.02,
#  9207.92,
#  8826.96,
#  9288.2,
#  9665.49,
#  9406.94,
#  9265.825,
#  9260.34,
#  9618.38,
#  9037.16,
#  9758.94,
#  9160.53,
#  9528.88,
#  9432.99,
#  9814.605,
#  9377.2,
#  9337.595,
#  8794.895,
#  9914.775,
#  8985.295,
#  9641.515,
#  9457.72,
#  9380.945,
#  9475.17,
#  9319.275,
# ...

# %%
age_sample_mean7=[data[data['Age']=='55+'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean7
# Out:
# [8900.09,
#  8794.56,
#  9781.11,
#  8914.415,
#  9264.52,
#  9870.705,
#  9843.355,
#  9924.15,
#  9292.37,
#  9311.625,
#  9293.385,
#  9457.945,
#  9325.665,
#  9538.575,
#  9464.93,
#  9090.8,
#  9331.965,
#  9097.67,
#  9797.41,
#  8988.8,
#  8783.44,
#  9356.465,
#  9537.49,
#  9704.51,
#  9154.56,
#  9845.49,
#  8812.69,
#  8960.115,
#  9112.115,
#  9482.51,
#  9610.895,
#  9574.2,
#  9046.69,
#  9091.255,
#  9771.89,
#  9455.195,
#  10028.45,
#  9228.415,
#  9898.28,
#  9809.245,
#  9239.825,
#  8983.575,
#  9106.535,
#  9463.14,
#  9933.835,
#  9365.74,
#  9949.085,
#  9697.335,
#  9663.565,
#  9304.24,
#  9076.245,
#  9948.19,
#  10199.67,
#  9671.83,
#  9730.52,
#  9497.125,
#  9317.63,
#  9022.455,
#  9531.94,
#  9728.02,
#  8986.32,
#  8834.29,
#  9809.325,
#  9585.185,
#  9373.335,
#  9139.465,
#  9404.265,
#  9826.675,
#  9527.975,
#  9777.62,
#  9360.67,
#  9991.555,
#  9622.835,
#  9213.995,
#  8789.155,
#  9234.995,
#  9312.93,
#  9574.425,
#  8698.66,
#  9415.985,
# ...

# %%
sns.histplot(age_sample_mean1, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(age_sample_mean2, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(age_sample_mean3, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(age_sample_mean4, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(age_sample_mean5, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(age_sample_mean6, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(age_sample_mean7, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
age_95_confidence_interval11=np.percentile(age_sample_mean1,[2.5,97.5])
age_95_confidence_interval11
# Out:
# array([8178.3565  , 9671.520875])

# %%
age_99_confidence_interval11=np.percentile(age_sample_mean1,[0.5, 99.5])
age_99_confidence_interval11
# Out:
# array([7960.5315  , 9866.475425])

# %%
age_95_confidence_interval12=np.percentile(age_sample_mean2,[2.5,97.5])
age_95_confidence_interval12
# Out:
# array([8460.875375, 9838.536625])

# %%
age_99_confidence_interval12=np.percentile(age_sample_mean2,[0.5, 99.5])
age_99_confidence_interval12
# Out:
# array([ 8278.301425, 10010.216325])

# %%
age_95_confidence_interval13=np.percentile(age_sample_mean3,[2.5,97.5])
age_95_confidence_interval13
# Out:
# array([8589.2755  , 9995.486125])

# %%
age_99_confidence_interval13=np.percentile(age_sample_mean3,[0.5, 99.5])
age_99_confidence_interval13
# Out:
# array([ 8384.238675, 10173.087325])

# %%
age_95_confidence_interval14=np.percentile(age_sample_mean4,[2.5,97.5])
age_95_confidence_interval14
# Out:
# array([ 8656.035125, 10026.602   ])

# %%
age_99_confidence_interval14=np.percentile(age_sample_mean4,[0.5, 99.5])
age_99_confidence_interval14
# Out:
# array([ 8427.2243  , 10263.825325])

# %%
age_95_confidence_interval15=np.percentile(age_sample_mean5,[2.5,97.5])
age_95_confidence_interval15
# Out:
# array([8578.4695  , 9849.720375])

# %%
age_99_confidence_interval15=np.percentile(age_sample_mean5,[0.5, 99.5])
age_99_confidence_interval15
# Out:
# array([ 8441.0264 , 10048.24475])

# %%
age_95_confidence_interval16=np.percentile(age_sample_mean6,[2.5,97.5])
age_95_confidence_interval16
# Out:
# array([ 8826.77475, 10252.19725])

# %%
age_99_confidence_interval16=np.percentile(age_sample_mean6,[0.5, 99.5])
age_99_confidence_interval16
# Out:
# array([ 8597.8899, 10459.1861])

# %%
age_95_confidence_interval17=np.percentile(age_sample_mean7,[2.5,97.5])
age_95_confidence_interval17
# Out:
# array([ 8668.136375, 10028.53375 ])

# %%
age_99_confidence_interval17=np.percentile(age_sample_mean7,[0.5, 99.5])
age_99_confidence_interval17
# Out:
# array([ 8497.48515 , 10199.894675])

# %%
#sample size = 500 , iterations = 2000

# %%
size=500
n = 2000

# %%
age_sample_mean11=[data[data['Age']=='0-17'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean11
# Out:
# [8499.878,
#  9113.808,
#  9015.484,
#  8678.996,
#  9148.772,
#  8944.784,
#  8637.41,
#  8990.15,
#  9217.548,
#  8784.308,
#  8806.676,
#  8388.32,
#  9036.694,
#  8894.468,
#  9396.236,
#  8772.344,
#  9396.598,
#  9048.442,
#  8719.416,
#  8857.978,
#  9025.672,
#  8886.318,
#  8976.938,
#  8984.118,
#  9025.624,
#  8725.12,
#  8539.062,
#  8812.308,
#  8658.684,
#  8793.376,
#  8900.892,
#  9337.536,
#  8985.116,
#  9220.494,
#  8830.5,
#  9240.42,
#  8980.392,
#  9125.148,
#  9046.032,
#  9041.856,
#  8383.316,
#  8667.06,
#  8738.918,
#  8931.96,
#  8602.176,
#  9028.322,
#  8964.186,
#  8601.722,
#  8947.604,
#  9067.028,
#  9477.328,
#  8813.498,
#  8697.184,
#  8608.516,
#  9063.91,
#  9145.41,
#  9070.624,
#  8738.048,
#  9096.852,
#  9215.454,
#  9001.956,
#  8567.512,
#  9277.252,
#  8832.844,
#  8851.724,
#  9025.232,
#  8652.226,
#  8824.912,
#  8854.78,
#  8456.884,
#  9034.29,
#  9337.618,
#  8803.526,
#  8548.528,
#  9103.688,
#  9203.878,
#  9042.872,
#  8737.81,
# ...

# %%
age_sample_mean22=[data[data['Age']=='18-25'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean22
# Out:
# [8797.296,
#  9171.234,
#  8584.086,
#  9228.508,
#  9417.562,
#  9245.322,
#  9294.412,
#  8872.688,
#  9175.278,
#  9185.302,
#  9283.316,
#  9267.332,
#  8813.538,
#  8851.022,
#  8921.072,
#  9152.328,
#  8810.282,
#  9381.764,
#  9413.946,
#  9284.272,
#  8822.064,
#  9151.952,
#  9054.042,
#  9192.858,
#  9252.638,
#  9155.636,
#  9342.806,
#  8852.092,
#  8710.0,
#  9103.592,
#  9288.216,
#  9355.886,
#  9152.466,
#  9487.06,
#  9211.99,
#  9043.584,
#  9150.92,
#  8746.896,
#  9165.066,
#  9045.312,
#  9342.674,
#  9052.148,
#  9191.546,
#  9543.552,
#  9205.464,
#  9263.774,
#  9271.644,
#  8971.928,
#  9190.38,
#  9075.72,
#  9023.024,
#  8872.614,
#  9094.214,
#  8733.478,
#  9356.992,
#  9271.47,
#  9319.08,
#  8998.64,
#  9263.46,
#  9249.774,
#  9005.094,
#  9100.65,
#  9234.982,
#  9532.754,
#  8995.77,
#  9413.704,
#  9287.96,
#  9127.63,
#  9060.832,
#  9150.28,
#  9324.058,
#  9069.224,
#  9231.22,
#  9292.888,
#  9101.456,
#  9555.852,
#  9244.686,
#  9036.146,
# ...

# %%
age_sample_mean33=[data[data['Age']=='26-35'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean33
# Out:
# [9081.372,
#  9412.226,
#  8940.476,
#  9312.594,
#  9081.786,
#  9018.488,
#  9398.062,
#  8942.792,
#  8959.06,
#  9604.094,
#  9206.222,
#  9061.914,
#  9112.332,
#  9340.248,
#  9187.456,
#  9492.522,
#  9268.006,
#  8885.588,
#  9349.318,
#  9316.57,
#  9370.808,
#  9078.184,
#  9411.254,
#  9264.192,
#  9354.918,
#  9339.04,
#  8672.31,
#  9039.234,
#  9640.862,
#  9254.83,
#  8933.656,
#  8686.024,
#  9216.174,
#  9106.844,
#  9226.702,
#  8604.568,
#  9129.06,
#  9362.386,
#  9409.822,
#  9190.636,
#  9118.328,
#  8928.942,
#  9165.646,
#  9220.064,
#  9598.328,
#  9203.82,
#  8919.862,
#  9152.972,
#  9185.314,
#  9276.552,
#  9096.312,
#  9272.796,
#  9138.814,
#  9126.212,
#  9057.752,
#  9469.312,
#  9272.518,
#  9185.538,
#  9323.402,
#  9163.38,
#  9054.888,
#  9622.886,
#  9778.962,
#  9119.452,
#  9278.074,
#  9170.036,
#  9336.398,
#  8995.302,
#  9080.334,
#  9145.178,
#  9786.552,
#  9200.51,
#  9703.354,
#  9431.944,
#  9655.928,
#  9444.134,
#  9285.638,
# ...

# %%
age_sample_mean44=[data[data['Age']=='36-45'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean44
# Out:
# [9290.148,
#  9387.434,
#  9443.35,
#  9184.272,
#  9628.604,
#  9204.042,
#  9378.44,
#  9128.138,
#  9047.054,
#  9327.124,
#  9081.254,
#  9521.724,
#  9622.558,
#  9024.066,
#  9234.92,
#  9458.606,
#  9671.106,
#  9503.756,
#  9202.218,
#  9675.764,
#  9481.93,
#  9603.546,
#  9443.87,
#  9297.188,
#  9309.008,
#  9564.67,
#  9328.504,
#  9378.562,
#  9211.964,
#  9028.506,
#  9117.526,
#  9146.402,
#  8841.046,
#  9160.148,
#  9099.262,
#  9038.788,
#  9189.88,
#  8846.994,
#  9343.194,
#  9608.578,
#  9312.29,
#  9563.37,
#  9250.142,
#  9279.198,
#  9344.466,
#  9520.946,
#  8944.114,
#  9512.606,
#  9128.118,
#  9278.4,
#  9250.954,
#  8895.25,
#  9013.638,
#  9558.056,
#  9283.672,
#  9215.12,
#  9130.814,
#  9392.454,
#  9307.922,
#  9421.82,
#  8987.666,
#  9200.06,
#  9368.456,
#  9382.008,
#  9243.594,
#  9706.272,
#  9213.46,
#  9336.542,
#  9353.062,
#  8770.476,
#  9772.138,
#  9315.374,
#  9345.87,
#  9393.866,
#  9381.062,
#  9406.062,
#  9409.776,
#  9560.922,
# ...

# %%
age_sample_mean55=[data[data['Age']=='46-50'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean55
# Out:
# [8825.1,
#  9413.388,
#  8999.576,
#  9337.766,
#  9305.132,
#  8956.286,
#  8930.154,
#  9607.256,
#  9322.474,
#  9225.314,
#  9246.974,
#  9060.586,
#  9023.11,
#  9078.164,
#  8893.34,
#  9055.76,
#  9147.7,
#  8994.052,
#  8698.746,
#  9077.83,
#  9224.376,
#  9380.5,
#  9023.884,
#  9217.898,
#  8885.84,
#  8830.696,
#  9238.272,
#  9195.924,
#  9270.832,
#  9503.934,
#  9630.102,
#  9028.212,
#  9006.776,
#  8844.67,
#  9251.058,
#  9054.366,
#  9274.29,
#  9494.544,
#  9369.02,
#  9061.576,
#  9482.464,
#  9257.806,
#  9471.608,
#  9012.022,
#  9458.112,
#  8893.698,
#  9075.604,
#  9405.508,
#  8949.818,
#  9432.518,
#  9190.794,
#  9220.1,
#  9275.586,
#  9621.44,
#  9240.08,
#  8941.892,
#  9129.14,
#  9071.136,
#  9757.644,
#  9417.548,
#  8783.078,
#  9203.404,
#  9183.558,
#  9059.622,
#  9612.14,
#  9138.17,
#  9282.78,
#  9267.234,
#  9029.232,
#  9475.378,
#  9116.912,
#  9105.588,
#  9127.654,
#  9214.072,
#  9204.974,
#  9105.522,
#  9065.662,
#  9330.368,
# ...

# %%
age_sample_mean66=[data[data['Age']=='51-55'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean66
# Out:
# [9600.294,
#  9548.552,
#  9343.178,
#  9623.246,
#  9404.744,
#  9104.896,
#  9346.13,
#  9497.954,
#  9188.038,
#  9571.6,
#  9300.572,
#  9942.848,
#  9540.652,
#  9523.518,
#  9584.85,
#  9400.892,
#  9191.808,
#  9569.322,
#  9417.622,
#  9261.046,
#  9571.278,
#  9507.274,
#  9725.342,
#  9602.626,
#  9380.894,
#  9234.984,
#  9754.378,
#  9488.686,
#  9622.69,
#  9563.47,
#  9396.68,
#  9433.968,
#  9670.092,
#  9686.694,
#  9474.554,
#  9561.658,
#  9670.842,
#  9405.024,
#  9610.908,
#  9251.85,
#  9699.148,
#  9459.022,
#  9578.194,
#  9668.748,
#  9185.454,
#  9580.594,
#  9570.432,
#  9349.1,
#  9359.496,
#  9723.132,
#  9183.222,
#  9264.538,
#  9880.19,
#  9636.054,
#  9491.038,
#  9691.802,
#  9268.366,
#  9211.448,
#  9341.79,
#  9513.632,
#  9448.24,
#  9466.298,
#  9510.588,
#  9553.958,
#  8989.268,
#  9704.018,
#  9655.744,
#  9552.622,
#  9694.43,
#  9057.63,
#  9271.014,
#  9708.258,
#  9570.358,
#  9935.784,
#  9949.578,
#  9623.218,
#  9380.84,
#  9470.768,
# ...

# %%
age_sample_mean77=[data[data['Age']=='55+'].sample(size)['Purchase'].mean() for i in range(n)]
age_sample_mean77
# Out:
# [9302.228,
#  9610.214,
#  9087.666,
#  9355.948,
#  9723.254,
#  9173.812,
#  9217.68,
#  8977.016,
#  9599.704,
#  9493.714,
#  9186.144,
#  9280.136,
#  9250.066,
#  9856.038,
#  9436.792,
#  9304.88,
#  9373.698,
#  9015.478,
#  9105.464,
#  9294.944,
#  9009.748,
#  9323.668,
#  9291.09,
#  9524.444,
#  9306.61,
#  9617.604,
#  9358.926,
#  9147.814,
#  8899.292,
#  9668.01,
#  9454.308,
#  9486.836,
#  9592.522,
#  9017.09,
#  9086.74,
#  9231.774,
#  9312.19,
#  9683.252,
#  9514.852,
#  9429.862,
#  9177.498,
#  9568.816,
#  9406.772,
#  9369.9,
#  9313.026,
#  9329.932,
#  9361.292,
#  9262.612,
#  9269.172,
#  9047.972,
#  9761.796,
#  9102.392,
#  9565.094,
#  9557.436,
#  9164.964,
#  9206.88,
#  9070.98,
#  9518.462,
#  9317.674,
#  9289.872,
#  9049.176,
#  9535.526,
#  9567.416,
#  9135.206,
#  9028.276,
#  9030.466,
#  9446.15,
#  9117.696,
#  9229.608,
#  9849.268,
#  9233.232,
#  8917.64,
#  9429.478,
#  9379.546,
#  9754.338,
#  9159.902,
#  9490.3,
#  9079.62,
# ...

# %%
sns.histplot(age_sample_mean11, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(age_sample_mean22, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(age_sample_mean33, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(age_sample_mean44, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(age_sample_mean55, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(age_sample_mean66, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(age_sample_mean77, kde = True)
plt.show()
# Out:
# C:\Users\Jalaj\Newfolder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
age_95_confidence_interval21=np.percentile(age_sample_mean11,[2.5,97.5])
age_95_confidence_interval21
# Out:
# array([8501.88845, 9396.62755])

# %%
age_99_confidence_interval21=np.percentile(age_sample_mean11,[0.5, 99.5])
age_99_confidence_interval21
# Out:
# array([8388.29498, 9567.17812])

# %%
age_95_confidence_interval22=np.percentile(age_sample_mean22,[2.5,97.5])
age_95_confidence_interval22
# Out:
# array([8720.40445, 9598.5794 ])

# %%
age_99_confidence_interval22=np.percentile(age_sample_mean22,[0.5, 99.5])
age_99_confidence_interval22
# Out:
# array([8640.31317, 9703.86618])

# %%
age_95_confidence_interval33=np.percentile(age_sample_mean33,[2.5,97.5])
age_95_confidence_interval33
# Out:
# array([8826.3753 , 9696.58265])

# %%
age_99_confidence_interval33=np.percentile(age_sample_mean33,[0.5, 99.5])
age_99_confidence_interval33
# Out:
# array([8677.33674, 9804.55089])

# %%
age_95_confidence_interval44=np.percentile(age_sample_mean44,[2.5,97.5])
age_95_confidence_interval44
# Out:
# array([8895.1836, 9743.0482])

# %%
age_99_confidence_interval44=np.percentile(age_sample_mean44,[0.5, 99.5])
age_99_confidence_interval44
# Out:
# array([8780.95175, 9933.25755])

# %%
age_95_confidence_interval55=np.percentile(age_sample_mean55,[2.5,97.5])
age_95_confidence_interval55
# Out:
# array([8783.62205, 9647.01065])

# %%
age_99_confidence_interval55=np.percentile(age_sample_mean55,[0.5, 99.5])
age_99_confidence_interval55
# Out:
# array([8666.56793, 9789.63613])

# %%
age_95_confidence_interval66=np.percentile(age_sample_mean66,[2.5,97.5])
age_95_confidence_interval66
# Out:
# array([9106.64125, 9962.3289 ])

# %%
age_99_confidence_interval66=np.percentile(age_sample_mean66,[0.5, 99.5])
age_99_confidence_interval66
# Out:
# array([ 8986.89753, 10109.32299])

# %%
age_95_confidence_interval77=np.percentile(age_sample_mean77,[2.5,97.5])
age_95_confidence_interval77
# Out:
# array([8896.28175, 9775.42305])

# %%
age_99_confidence_interval77=np.percentile(age_sample_mean77,[0.5, 99.5])
age_99_confidence_interval77
# Out:
# array([8757.5983 , 9892.78833])

# %%
# Age 0-17 95% Confidence Interaval
print(f"1.{age_95_confidence_interval11}")
print(f"2.{age_95_confidence_interval21}")
# Out:
# 1.[8178.3565   9671.520875]
# 2.[8501.88845 9396.62755]

# %%
# Age 0-17 99% Confidence Interaval
print(f"1.{age_99_confidence_interval11}")
print(f"2.{age_99_confidence_interval21}")
# Out:
# 1.[7960.5315   9866.475425]
# 2.[8388.29498 9567.17812]

# %%
# Age 18-25 95% Confidence Interaval
print(f"1.{age_95_confidence_interval12}")
print(f"2.{age_95_confidence_interval22}")
# Out:
# 1.[8460.875375 9838.536625]
# 2.[8720.40445 9598.5794 ]

# %%
# Age 18-25 99% Confidence Interaval
print(f"1.{age_99_confidence_interval12}")
print(f"2.{age_99_confidence_interval22}")
# Out:
# 1.[ 8278.301425 10010.216325]
# 2.[8640.31317 9703.86618]

# %%
# Age 26-35 95% Confidence Interaval
print(f"1.{age_95_confidence_interval13}")
print(f"2.{age_95_confidence_interval33}")
# Out:
# 1.[8589.2755   9995.486125]
# 2.[8826.3753  9696.58265]

# %%
# Age 26-35 99% Confidence Interaval
print(f"1.{age_99_confidence_interval13}")
print(f"2.{age_99_confidence_interval33}")
# Out:
# 1.[ 8384.238675 10173.087325]
# 2.[8677.33674 9804.55089]

# %%
# Age 36-45 95% Confidence Interaval
print(f"1.{age_95_confidence_interval14}")
print(f"2.{age_95_confidence_interval44}")
# Out:
# 1.[ 8656.035125 10026.602   ]
# 2.[8895.1836 9743.0482]

# %%
# Age 36-45 99% Confidence Interaval
print(f"1.{age_99_confidence_interval14}")
print(f"2.{age_99_confidence_interval44}")
# Out:
# 1.[ 8427.2243   10263.825325]
# 2.[8780.95175 9933.25755]

# %%
# Age 46-50 95% Confidence Interaval
print(f"1.{age_95_confidence_interval15}")
print(f"2.{age_95_confidence_interval55}")
# Out:
# 1.[8578.4695   9849.720375]
# 2.[8783.62205 9647.01065]

# %%
# Age 46-50 99% Confidence Interaval
print(f"1.{age_99_confidence_interval15}")
print(f"2.{age_99_confidence_interval55}")
# Out:
# 1.[ 8441.0264  10048.24475]
# 2.[8666.56793 9789.63613]

# %%
# Age 51-55 95% Confidence Interaval
print(f"1.{age_95_confidence_interval16}")
print(f"2.{age_95_confidence_interval66}")
# Out:
# 1.[ 8826.77475 10252.19725]
# 2.[9106.64125 9962.3289 ]

# %%
# Age 51-55 99% Confidence Interaval
print(f"1.{age_99_confidence_interval16}")
print(f"2.{age_99_confidence_interval66}")
# Out:
# 1.[ 8597.8899 10459.1861]
# 2.[ 8986.89753 10109.32299]

# %%
# Age 55+ 95% Confidence Interaval
print(f"1.{age_95_confidence_interval17}")
print(f"2.{age_95_confidence_interval77}")
# Out:
# 1.[ 8668.136375 10028.53375 ]
# 2.[8896.28175 9775.42305]

# %%
# Age 55+ 99% Confidence Interaval
print(f"1.{age_99_confidence_interval17}")
print(f"2.{age_99_confidence_interval77}")
# Out:
# 1.[ 8497.48515  10199.894675]
# 2.[8757.5983  9892.78833]

# %%
## BUSSINESS INSIGHTS

# %%
# Based on the Central Limit Theoram we can not conclude that male or female , or , married  or unmarried ,
# or differend age group, spends more amount than the other

# %%
# People in te age-group 26-35 stay in the same city more than the others .

# %%
# People in the age-group 26-35 buy products from product category 1,5,8 most.

# %%
# Product category 1,5,8 are  most bought products

# %%
# UNmarried People tend to stay more in a city than married people

# %%
# City cagtegory type B spends most amount money and category type c spend teh least ( total amnount spent)

# %%
# Unmarried people spend more than married people.

# %%
# mean amount spend by all the occupation is same but occupation category 4 & 1 spend most amount.

# %%
## RECOMENDATIONS

# %%
# As we have found out that wee can't come to a conclusion that male or females spend more than each other ,
# so instead of gender based targetting or promotions we can give offers and promotions based on individual spending pattern.

# %%
# The company should focus more on cities in the category type B( as it spends the most amount) .
# It should manage inventory , adjust pricing and offer promotions in those cities.

# %%
# People in the age group 26-35  spend most amount of money and stay in a specific city more ,
# the company can target based on demographics and offers promotions and offers

# %%
# Some product category are brought more than others , we can check whether these product need promotions or offers ,
# if not then we can focus more on the product that are less bought and offer promotions and discounts on them.
